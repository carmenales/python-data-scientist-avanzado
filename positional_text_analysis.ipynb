# %%
import nltk
import string
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
#nltk.download("punkt")
#nltk.download("stopwords")
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\carmen.ales\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\carmen.ales\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\carmen.ales\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
txt = open("example_english.txt", "r").read()

# %%
stop_words = stopwords.words("english")

words = [x for x in word_tokenize(txt.lower()) if x not in stop_words + list(string.punctuation)]

# %%
stemmer = SnowballStemmer("english")
lem = WordNetLemmatizer()

print(stemmer.stem("run"))
print(lem.lemmatize("running", "v"))
# Out:
# run
# run

# %%
nltk.pos_tag(words)
# Out:
# [('countries', 'NNS'),
#  ('dedicate', 'VBP'),
#  ('national', 'JJ'),
#  ('public', 'JJ'),
#  ('holiday', 'NN'),
#  ('reconciliation', 'NN'),
#  ('nations', 'NNS'),
#  ('history', 'NN'),
#  ('enforced', 'VBN'),
#  ('division', 'NN'),
#  ('oppression', 'NN'),
#  ('sustained', 'VBD'),
#  ('conflict', 'NN'),
#  ('fewer', 'NN'),
#  ('still', 'RB'),
#  ('undergone', 'JJ'),
#  ('remarkable', 'JJ'),
#  ('transition', 'NN'),
#  ('reclaim', 'NN'),
#  ('humanity', 'NN'),
#  ('people', 'NNS'),
#  ('south', 'VBP'),
#  ('africa', 'JJ'),
#  ('made', 'VBN'),
#  ('decisive', 'JJ'),
#  ('irreversible', 'JJ'),
#  ('break', 'NN'),
#  ('past', 'IN'),
#  ('real', 'JJ'),
#  ('life', 'NN'),
#  ('declared', 'VBN'),
#  ('shared', 'VBN'),
#  ('allegiance', 'NN'),
#  ('justice', 'NN'),
#  ('non-racialism', 'NN'),
#  ('democracy', 'NN'),
#  ('yearning', 'VBG'),
#  ('peaceful', 'JJ'),
#  ('harmonious', 'JJ'),
#  ('nation', 'NN'),
#  ('equals', 'NNS'),
#  ('rainbow', 'VBP'),
#  ('come', 'JJ'),
#  ('symbol', 'NN'),
#  ('nation', 'NN'),
#  ('turning', 'VBG'),
#  ('variety', 'NN'),
#  ('languages', 'NNS'),
#  ('cultures', 'NNS'),
#  ('used', 'VBD'),
#  ('divide', 'JJ'),
#  ('us', 'PRP'),
#  ('source', 'NN'),
#  ('strength', 'NN'),
#  ('richness', 'NN'),
#  ('know', 'VBP'),
#  ('healing', 'VBG'),
#  ('wounds', 'NNS'),
#  ('past', 'JJ'),
#  ('freeing', 'VBG'),
#  ('burden', 'NN'),
#  ('long', 'RB'),
#  ('demanding', 'VBG'),
#  ('task', 'NN'),
#  ('day', 'NN'),
#  ('reconciliation', 'NN'),
#  ('celebrates', 'VBZ'),
#  ('progress', 'NN'),
#  ('made', 'VBD'),
#  ('reaffirms', 'NNS'),
#  ('commitment', 'JJ'),
#  ('measures', 'NNS'),
#  ('challenges', 'VBZ'),
#  ('government', 'NN'),
#  ('national', 'JJ'),
#  ('unity', 'NN'),
#  ('chose', 'VBD'),
#  ('day', 'NN'),
#  ('precisely', 'RB'),
#  ('past', 'IN'),
#  ('made', 'VBN'),
#  ('december', 'NN'),
#  ('16', 'CD'),
#  ('living', 'NN'),
#  ('symbol', 'NN'),
#  ('bitter', 'JJ'),
#  ('division', 'NN'),
#  ('valour', 'NN'),
#  ('measured', 'VBD'),
#  ('number', 'NN'),
#  ('enemies', 'NNS'),
#  ('killed', 'VBN'),
#  ('quantity', 'NN'),
#  ('blood', 'NN'),
#  ('swelled', 'VBD'),
#  ('rivers', 'NNS'),
#  ('flowed', 'VBD'),
#  ('streets', 'NNS'),
#  ('today', 'NN'),
#  ('longer', 'RB'),
#  ('vow', 'JJ'),
#  ('mutual', 'JJ'),
#  ('destruction', 'NN'),
#  ('solemnly', 'RB'),
#  ('acknowledge', 'VBZ'),
#  ('inter-dependence', 'NN'),
#  ('free', 'JJ'),
#  ('equal', 'JJ'),
#  ('citizens', 'NNS'),
#  ('common', 'JJ'),
#  ('motherland', 'NN'),
#  ('today', 'NN'),
#  ('re-affirm', 'JJ'),
#  ('solemn', 'JJ'),
#  ('constitutional', 'JJ'),
#  ('compact', 'JJ'),
#  ('live', 'JJ'),
#  ('together', 'RB'),
#  ('basis', 'NN'),
#  ('equality', 'NN'),
#  ('mutual', 'JJ'),
#  ('respect', 'NN'),
#  ('reconciliation', 'NN'),
#  ('however', 'RB'),
#  ('mean', 'JJ'),
#  ('forgetting', 'VBG'),
#  ('trying', 'VBG'),
#  ('bury', 'NN'),
#  ('pain', 'NN'),
#  ('conflict', 'NN'),
#  ('two', 'CD'),
#  ('terrible', 'JJ'),
#  ('defects', 'NNS'),
#  ('weakened', 'VBD'),
#  ('foundations', 'NNS'),
#  ('modern', 'JJ'),
#  ('south', 'JJ'),
#  ('african', 'JJ'),
#  ('state', 'NN'),
#  ('laid', 'VBD'),
#  ('great', 'JJ'),
#  ('upheaval', 'JJ'),
#  ('beginning', 'VBG'),
#  ('century', 'NN'),
#  ('firstly', 'RB'),
#  ('rested', 'VBD'),
#  ('treacherous', 'JJ'),
#  ('swamps', 'NNS'),
#  ('racism', 'NN'),
#  ('inequality', 'NN'),
#  ('second', 'JJ'),
#  ('defect', 'JJ'),
#  ('suppression', 'NN'),
#  ('truth', 'NN'),
#  ('end', 'JJ'),
#  ('century', 'NN'),
#  ('south', 'NN'),
#  ('africans', 'NNS'),
#  ('real', 'JJ'),
#  ('chance', 'NN'),
#  ('strike', 'NN'),
#  ('along', 'IN'),
#  ('glorious', 'JJ'),
#  ('path', 'NN'),
#  ('democratic', 'JJ'),
#  ('foundations', 'NNS'),
#  ('society', 'NN'),
#  ('laid', 'NN'),
#  ('must', 'MD'),
#  ('use', 'VB'),
#  ('collective', 'JJ'),
#  ('strengths', 'NNS'),
#  ('carry', 'VBP'),
#  ('building', 'VBG'),
#  ('nation', 'NN'),
#  ('improving', 'VBG'),
#  ('quality', 'NN'),
#  ('life', 'NN'),
#  ('truth', 'VBP'),
#  ('national', 'JJ'),
#  ('reconciliation', 'NN'),
#  ('commission', 'NN'),
#  ('soon', 'RB'),
#  ('begin', 'JJ'),
#  ('work', 'VBP'),
#  ('one', 'CD'),
#  ('important', 'JJ'),
#  ('institution', 'NN'),
#  ('created', 'VBD'),
#  ('democratic', 'JJ'),
#  ('constitution', 'NN'),
#  ('parliament', 'NN'),
#  ('order', 'NN'),
#  ('help', 'VBP'),
#  ('us', 'PRP'),
#  ('manage', 'VB'),
#  ('difficult', 'JJ'),
#  ('aspects', 'NNS'),
#  ('healing', 'VBG'),
#  ('nation', 'NN'),
#  ("'s", 'POS'),
#  ('wounds', 'NNS'),
#  ('thus', 'RB'),
#  ('shall', 'MD'),
#  ('free', 'VB'),
#  ('burden', 'JJ'),
#  ('yester-year', 'JJ'),
#  ('return', 'NN'),
#  ('move', 'NN'),
#  ('forward', 'RB'),
#  ('confidence', 'NN'),
#  ('free', 'JJ'),
#  ('men', 'NNS'),
#  ('women', 'NNS'),
#  ('committed', 'VBD'),
#  ('attain', 'NN'),
#  ('best', 'JJS'),
#  ('future', 'JJ'),
#  ('generations', 'NNS'),
#  ('reconciliation', 'NN'),
#  ('means', 'VBZ'),
#  ('working', 'VBG'),
#  ('together', 'RB'),
#  ('correct', 'JJ'),
#  ('legacy', 'NN'),
#  ('past', 'IN'),
#  ('injustice', 'NN'),
#  ('means', 'NNS'),
#  ('making', 'VBG'),
#  ('success', 'NN'),
#  ('plans', 'NNS'),
#  ('reconstruction', 'VBP'),
#  ('development', 'NN'),
#  ('therefore', 'IN'),
#  ('december', '$'),
#  ('16', 'CD'),
#  ('national', 'JJ'),
#  ('day', 'NN'),
#  ('reconciliation', 'NN'),
#  ('appeal', 'NN'),
#  ('fellow', 'JJ'),
#  ('citizens', 'NNS'),
#  ('let', 'VBP'),
#  ('us', 'PRP'),
#  ('join', 'VB'),
#  ('hands', 'NNS'),
#  ('build', 'VB'),
#  ('truly', 'RB'),
#  ('south', 'JJ'),
#  ('african', 'JJ'),
#  ('nation', 'NN')]

# %%
def get_wordnet_pos(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
    
    return tag_dict.get(tag, wordnet.NOUN)

# %%
phrases = nltk.sent_tokenize(txt)
phrases
# Out:
# ['There are few countries which dedicate a national public holiday to reconciliation.',
#  'But then there are few nations with our history of enforced division, oppression and sustained conflict.',
#  'And fewer still, which have undergone such a remarkable transition to reclaim their humanity.',
#  'We, the people of South Africa, have made a decisive and irreversible break with the past.',
#  'We have, in real life, declared our shared allegiance to justice, non-racialism and democracy; our yearning for a peaceful and harmonious nation of equals.',
#  'The rainbow has come to be the symbol of our nation.',
#  'We are turning the variety of our languages and cultures, once used to divide us, into a source of strength and richness.',
#  'But we do know that healing the wounds of the past and freeing ourselves of its burden will be a long and demanding task.',
#  'This Day of Reconciliation celebrates the progress we have made; it reaffirms our commitment; and it measures the challenges.',
#  'The Government of National Unity chose this day precisely because the past had made December 16 a living symbol of bitter division.',
#  'Valour was measured by the number of enemies killed and the quantity of blood that swelled the rivers and flowed in the streets.',
#  'Today we no longer vow our mutual destruction but solemnly acknowledge our inter-dependence as free and equal citizens of our common Motherland.',
#  'Today we re-affirm our solemn constitutional compact to live together on the basis of equality and mutual respect.',
#  'Reconciliation however, does not mean forgetting or trying to bury the pain of conflict.',
#  'Two terrible defects weakened the foundations of the modern South African state that were laid in the great upheaval at the beginning of the century.',
#  'Firstly, it rested on the treacherous swamps of racism and inequality.',
#  'The second defect was the suppression of truth.',
#  'Now, at the end of the century, South Africans have the real chance to strike out along a glorious path.',
#  'The democratic foundations of our society have been laid.',
#  'We must use our collective strengths to carry on building the nation and improving its quality of life.',
#  "The Truth and National Reconciliation Commission which will soon begin its work, is one important institution created by our democratic Constitution and Parliament in order to help us manage the more difficult aspects of healing the nation's wounds.",
#  'Thus we shall free ourselves from the burden of yester-year; not to return there; but to move forward with the confidence of free men and women, committed to attain the best for ourselves and future generations.',
#  'Reconciliation means working together to correct the legacy of past injustice.',
#  'It means making a success of our plans for reconstruction and development.',
#  'Therefore, on this December 16, National Day of Reconciliation, my appeal to you, fellow citizens, is: Let us join hands and build a truly South African nation.']

# %%
for phrase in phrases:
    for word in nltk.word_tokenize(phrase):
        print(lem.lemmatize(word, get_wordnet_pos(word)))
# Out:
# There
# be
# few
# country
# which
# dedicate
# a
# national
# public
# holiday
# to
# reconciliation
# .
# But
# then
# there
# be
# few
# nation
# with
# our
# history
# of
# enforce
# division
# ,
# oppression
# and
# sustain
# conflict
# .
# And
# few
# still
# ,
# which
# have
# undergone
# such
# a
# remarkable
# transition
# to
# reclaim
# their
# humanity
# .
# We
# ,
# the
# people
# of
# South
# Africa
# ,
# have
# make
# a
# decisive
# and
# irreversible
# break
# with
# the
# past
# .
# We
# have
# ,
# in
# real
# life
# ,
# declare
# our
# share
# allegiance
# to
# justice
# ,
# non-racialism
# and
# democracy
# ;
# our
# yearn
# for
# a
# peaceful
# and
# harmonious
# nation
# of
# equal
# .
# The
# rainbow
# have
# come
# to
# be
# the
# symbol
# of
# our
# nation
# .
# We
# be
# turn
# the
# variety
# of
# our
# language
# and
# culture
# ,
# once
# use
# to
# divide
# u
# ,
# into
# a
# source
# of
# strength
# and
# richness
# .
# But
# we
# do
# know
# that
# heal
# the
# wound
# of
# the
# past
# and
# free
# ourselves
# of
# it
# burden
# will
# be
# a
# long
# and
# demand
# task
# .
# This
# Day
# of
# Reconciliation
# celebrates
# the
# progress
# we
# have
# make
# ;
# it
# reaffirms
# our
# commitment
# ;
# and
# it
# measure
# the
# challenge
# .
# The
# Government
# of
# National
# Unity
# chose
# this
# day
# precisely
# because
# the
# past
# have
# make
# December
# 16
# a
# living
# symbol
# of
# bitter
# division
# .
# Valour
# be
# measure
# by
# the
# number
# of
# enemy
# kill
# and
# the
# quantity
# of
# blood
# that
# swell
# the
# river
# and
# flow
# in
# the
# street
# .
# Today
# we
# no
# longer
# vow
# our
# mutual
# destruction
# but
# solemnly
# acknowledge
# our
# inter-dependence
# a
# free
# and
# equal
# citizen
# of
# our
# common
# Motherland
# .
# Today
# we
# re-affirm
# our
# solemn
# constitutional
# compact
# to
# live
# together
# on
# the
# basis
# of
# equality
# and
# mutual
# respect
# .
# Reconciliation
# however
# ,
# do
# not
# mean
# forget
# or
# try
# to
# bury
# the
# pain
# of
# conflict
# .
# Two
# terrible
# defect
# weaken
# the
# foundation
# of
# the
# modern
# South
# African
# state
# that
# be
# laid
# in
# the
# great
# upheaval
# at
# the
# begin
# of
# the
# century
# .
# Firstly
# ,
# it
# rest
# on
# the
# treacherous
# swamp
# of
# racism
# and
# inequality
# .
# The
# second
# defect
# be
# the
# suppression
# of
# truth
# .
# Now
# ,
# at
# the
# end
# of
# the
# century
# ,
# South
# Africans
# have
# the
# real
# chance
# to
# strike
# out
# along
# a
# glorious
# path
# .
# The
# democratic
# foundation
# of
# our
# society
# have
# be
# laid
# .
# We
# must
# use
# our
# collective
# strength
# to
# carry
# on
# building
# the
# nation
# and
# improve
# it
# quality
# of
# life
# .
# The
# Truth
# and
# National
# Reconciliation
# Commission
# which
# will
# soon
# begin
# it
# work
# ,
# be
# one
# important
# institution
# create
# by
# our
# democratic
# Constitution
# and
# Parliament
# in
# order
# to
# help
# u
# manage
# the
# more
# difficult
# aspect
# of
# heal
# the
# nation
# 's
# wound
# .
# Thus
# we
# shall
# free
# ourselves
# from
# the
# burden
# of
# yester-year
# ;
# not
# to
# return
# there
# ;
# but
# to
# move
# forward
# with
# the
# confidence
# of
# free
# men
# and
# woman
# ,
# commit
# to
# attain
# the
# best
# for
# ourselves
# and
# future
# generation
# .
# Reconciliation
# mean
# work
# together
# to
# correct
# the
# legacy
# of
# past
# injustice
# .
# It
# mean
# make
# a
# success
# of
# our
# plan
# for
# reconstruction
# and
# development
# .
# Therefore
# ,
# on
# this
# December
# 16
# ,
# National
# Day
# of
# Reconciliation
# ,
# my
# appeal
# to
# you
# ,
# fellow
# citizen
# ,
# be
# :
# Let
# u
# join
# hand
# and
# build
# a
# truly
# South
# African
# nation
# .
